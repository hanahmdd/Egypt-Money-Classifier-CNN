# %% [markdown]
# <a href="https://colab.research.google.com/github/hanahmdd/Egypt-Money-Classifier-CNN/blob/main/Copy_of_Egyptian_New_Currency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydot graphviz
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (0.21)
# Requirement already satisfied: pyparsing>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydot) (3.2.5)

# %%
import os
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import files


print(f"tensorFlow version: {tf.__version__}")
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f" runing on gpuu: {gpu_devices[0].name}")
else:
    print("remindd me to use gpuu")
# Out:
# tensorFlow version: 2.19.0
#  runing on gpuu: /physical_device:GPU:0

# %%
if os.path.exists('egyptian-new-currency-2023.zip'):
    os.remove('egyptian-new-currency-2023.zip')

print("\n upload kaggle.json file")
if not os.path.exists('kaggle.json'):
    files.upload()


os.system('mkdir -p ~/.kaggle')
os.system('cp kaggle.json ~/.kaggle/')
os.system('chmod 600 ~/.kaggle/kaggle.json')

print("downloading dataa")
os.system('kaggle datasets download -d belalsafy/egyptian-new-currency-2023')

print(" unziip")
with zipfile.ZipFile('egyptian-new-currency-2023.zip', 'r') as zip_ref:
    zip_ref.extractall('dataset_root')
# Out:
#  upload kaggle.json file
# downloading dataa
#  unziip

# %%
base_path = 'dataset_root'
if 'dataset' in os.listdir(base_path):
    base_path = os.path.join(base_path, 'dataset')


train_dir = os.path.join(base_path, 'train')
val_dir = os.path.join(base_path, 'validation')

test_dir = os.path.join(base_path, 'test')
print(f"[INFO] Test Directory:  {test_dir}")


if not os.path.exists(val_dir):
    if os.path.exists(os.path.join(base_path, 'valid')):
        val_dir = os.path.join(base_path, 'valid')
    elif os.path.exists(os.path.join(base_path, 'val')):
        val_dir = os.path.join(base_path, 'val')

print(f"\n[INFO] Train Directory: {train_dir}")
print(f"[INFO] Val Directory:   {val_dir}")

IMG_SIZE = (128, 128)
BATCH_SIZE = 32

#data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    brightness_range=[0.7, 1.3],
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)


test_generator = val_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

num_classes = train_generator.num_classes
class_names = list(train_generator.class_indices.keys())
print(f"\n[CHECK] Detected {num_classes} Classes: {class_names}")
# Out:
# [INFO] Test Directory:  dataset_root/dataset/test
#
# [INFO] Train Directory: dataset_root/dataset/train
# [INFO] Val Directory:   dataset_root/dataset/valid
# Found 2637 images belonging to 9 classes.
# Found 760 images belonging to 9 classes.
# Found 290 images belonging to 9 classes.
#
# [CHECK] Detected 9 Classes: ['1', '10', '10 (new)', '100', '20', '20 (new)', '200', '5', '50']

# %%
model = Sequential()

#block 1
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(128, 128, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

#block 2
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

#block 3
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

#block 4
model.add(Conv2D(256, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

#classification
model.add(Flatten())
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))


opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

tf.keras.utils.plot_model(model, to_file='model_architecture.png', show_shapes=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         4,617 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,971,401 (34.22 MB)
#  Trainable params: 8,969,033 (34.21 MB)
#  Non-trainable params: 2,368 (9.25 KB)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=1, min_lr=0.00001),
    EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
]

print("\n[startin train")

history = model.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# [info] starting training
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 71s 674ms/step - accuracy: 0.1411 - loss: 2.7446 - val_accuracy: 0.1053 - val_loss: 2.2062 - learning_rate: 0.0010
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.2513 - loss: 2.1980 - val_accuracy: 0.1684 - val_loss: 2.4586 - learning_rate: 0.0010
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 484ms/step - accuracy: 0.3175 - loss: 1.9909 - val_accuracy: 0.1868 - val_loss: 2.5719 - learning_rate: 0.0010
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 490ms/step - accuracy: 0.3185 - loss: 1.8797 - val_accuracy: 0.1961 - val_loss: 2.5034 - learning_rate: 0.0010
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 486ms/step - accuracy: 0.3701 - loss: 1.7871 - val_accuracy: 0.3316 - val_loss: 1.8659 - learning_rate: 0.0010
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.3942 - loss: 1.7587 - val_accuracy: 0.4039 - val_loss: 1.7107 - learning_rate: 0.0010
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.4235 - loss: 1.5515 - val_accuracy: 0.4250 - val_loss: 1.7070 - learning_rate: 0.0010
# Epoch 8/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 489ms/step - accuracy: 0.4450 - loss: 1.5018 - val_accuracy: 0.3500 - val_loss: 2.1138 - learning_rate: 0.0010
# Epoch 9/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 474ms/step - accuracy: 0.4910 - loss: 1.4071 - val_accuracy: 0.4789 - val_loss: 1.5548 - learning_rate: 0.0010
# Epoch 10/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 475ms/step - accuracy: 0.4920 - loss: 1.3342 - val_accuracy: 0.2750 - val_loss: 3.1297 - learning_rate: 0.0010
# Epoch 11/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 472ms/step - accuracy: 0.5269 - loss: 1.2850 - val_accuracy: 0.3500 - val_loss: 2.2198 - learning_rate: 0.0010
# Epoch 12/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.5429 - loss: 1.2223
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 482ms/step - accuracy: 0.5431 - loss: 1.2219 - val_accuracy: 0.3566 - val_loss: 2.7281 - learning_rate: 0.0010
# Epoch 13/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 474ms/step - accuracy: 0.5912 - loss: 1.0956 - val_accuracy: 0.4750 - val_loss: 1.7051 - learning_rate: 5.0000e-04
# Epoch 14/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.6395 - loss: 0.9870 - val_accuracy: 0.5947 - val_loss: 1.1524 - learning_rate: 5.0000e-04
# Epoch 15/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 464ms/step - accuracy: 0.6475 - loss: 0.9490 - val_accuracy: 0.5316 - val_loss: 1.3185 - learning_rate: 5.0000e-04
# Epoch 16/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 478ms/step - accuracy: 0.6652 - loss: 0.9181 - val_accuracy: 0.6039 - val_loss: 1.0662 - learning_rate: 5.0000e-04
# Epoch 17/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 528ms/step - accuracy: 0.6872 - loss: 0.8912 - val_accuracy: 0.6224 - val_loss: 1.0860 - learning_rate: 5.0000e-04
# Epoch 18/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.7134 - loss: 0.8340 - val_accuracy: 0.5553 - val_loss: 1.4524 - learning_rate: 5.0000e-04
# Epoch 19/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 474ms/step - accuracy: 0.7104 - loss: 0.8150 - val_accuracy: 0.6921 - val_loss: 0.8259 - learning_rate: 5.0000e-04
# Epoch 20/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 487ms/step - accuracy: 0.7308 - loss: 0.7627 - val_accuracy: 0.5197 - val_loss: 1.5539 - learning_rate: 5.0000e-04
# Epoch 21/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 469ms/step - accuracy: 0.7545 - loss: 0.7005 - val_accuracy: 0.7487 - val_loss: 0.6688 - learning_rate: 5.0000e-04
# Epoch 22/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.7716 - loss: 0.6732 - val_accuracy: 0.6500 - val_loss: 1.0463 - learning_rate: 5.0000e-04
# Epoch 23/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 464ms/step - accuracy: 0.7836 - loss: 0.6159 - val_accuracy: 0.6605 - val_loss: 1.1132 - learning_rate: 5.0000e-04
# Epoch 24/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 476ms/step - accuracy: 0.7700 - loss: 0.6748 - val_accuracy: 0.7697 - val_loss: 0.6312 - learning_rate: 5.0000e-04
# Epoch 25/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.7777 - loss: 0.6425 - val_accuracy: 0.5750 - val_loss: 1.4664 - learning_rate: 5.0000e-04
# Epoch 26/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 464ms/step - accuracy: 0.7875 - loss: 0.6040 - val_accuracy: 0.5750 - val_loss: 1.6326 - learning_rate: 5.0000e-04
# Epoch 27/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.7898 - loss: 0.5875
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.7898 - loss: 0.5872 - val_accuracy: 0.7447 - val_loss: 0.7611 - learning_rate: 5.0000e-04
# Epoch 28/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 472ms/step - accuracy: 0.8103 - loss: 0.5160 - val_accuracy: 0.7355 - val_loss: 0.7053 - learning_rate: 2.5000e-04
# Epoch 29/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.8486 - loss: 0.4296 - val_accuracy: 0.8184 - val_loss: 0.5278 - learning_rate: 2.5000e-04
# Epoch 30/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.8385 - loss: 0.4451 - val_accuracy: 0.8421 - val_loss: 0.4572 - learning_rate: 2.5000e-04
# Epoch 31/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 466ms/step - accuracy: 0.8513 - loss: 0.4427 - val_accuracy: 0.8118 - val_loss: 0.5440 - learning_rate: 2.5000e-04
# Epoch 32/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.8617 - loss: 0.4177 - val_accuracy: 0.8934 - val_loss: 0.3308 - learning_rate: 2.5000e-04
# Epoch 33/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 522ms/step - accuracy: 0.8758 - loss: 0.3769 - val_accuracy: 0.8395 - val_loss: 0.4545 - learning_rate: 2.5000e-04
# Epoch 34/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.8599 - loss: 0.4106 - val_accuracy: 0.7829 - val_loss: 0.6524 - learning_rate: 2.5000e-04
# Epoch 35/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8812 - loss: 0.3531
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.8812 - loss: 0.3532 - val_accuracy: 0.7974 - val_loss: 0.6481 - learning_rate: 2.5000e-04
# Epoch 36/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 478ms/step - accuracy: 0.8816 - loss: 0.3374 - val_accuracy: 0.9224 - val_loss: 0.2438 - learning_rate: 1.2500e-04
# Epoch 37/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.8929 - loss: 0.3216 - val_accuracy: 0.9132 - val_loss: 0.2671 - learning_rate: 1.2500e-04
# Epoch 38/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9076 - loss: 0.2971 - val_accuracy: 0.9237 - val_loss: 0.2398 - learning_rate: 1.2500e-04
# Epoch 39/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.9082 - loss: 0.2986 - val_accuracy: 0.8684 - val_loss: 0.4116 - learning_rate: 1.2500e-04
# Epoch 40/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 474ms/step - accuracy: 0.8980 - loss: 0.3024 - val_accuracy: 0.8947 - val_loss: 0.3139 - learning_rate: 1.2500e-04
# Epoch 41/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9025 - loss: 0.3081
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9025 - loss: 0.3080 - val_accuracy: 0.9237 - val_loss: 0.2484 - learning_rate: 1.2500e-04
# Epoch 42/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.9090 - loss: 0.2826 - val_accuracy: 0.9184 - val_loss: 0.2338 - learning_rate: 6.2500e-05
# Epoch 43/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.9073 - loss: 0.2829 - val_accuracy: 0.8882 - val_loss: 0.3460 - learning_rate: 6.2500e-05
# Epoch 44/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9244 - loss: 0.2537
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 464ms/step - accuracy: 0.9244 - loss: 0.2537 - val_accuracy: 0.9158 - val_loss: 0.2563 - learning_rate: 6.2500e-05
# Epoch 45/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 472ms/step - accuracy: 0.9300 - loss: 0.2367 - val_accuracy: 0.9250 - val_loss: 0.2466 - learning_rate: 3.1250e-05
# Epoch 46/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9008 - loss: 0.2871 - val_accuracy: 0.9184 - val_loss: 0.2450 - learning_rate: 3.1250e-05
# Epoch 47/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 472ms/step - accuracy: 0.9115 - loss: 0.2600 - val_accuracy: 0.9250 - val_loss: 0.2316 - learning_rate: 3.1250e-05
# Epoch 48/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 478ms/step - accuracy: 0.9097 - loss: 0.2618 - val_accuracy: 0.9329 - val_loss: 0.2172 - learning_rate: 3.1250e-05
# Epoch 49/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.9234 - loss: 0.2496 - val_accuracy: 0.9211 - val_loss: 0.2643 - learning_rate: 3.1250e-05
# Epoch 50/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.9245 - loss: 0.2338 - val_accuracy: 0.9276 - val_loss: 0.2130 - learning_rate: 3.1250e-05
# Epoch 51/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9125 - loss: 0.2662
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.9125 - loss: 0.2661 - val_accuracy: 0.9184 - val_loss: 0.2583 - learning_rate: 3.1250e-05
# Epoch 52/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.9154 - loss: 0.2482 - val_accuracy: 0.9289 - val_loss: 0.2194 - learning_rate: 1.5625e-05
# Epoch 53/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.9120 - loss: 0.2483 - val_accuracy: 0.9211 - val_loss: 0.2353 - learning_rate: 1.5625e-05
# Epoch 54/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9280 - loss: 0.2391
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 470ms/step - accuracy: 0.9279 - loss: 0.2391 - val_accuracy: 0.9316 - val_loss: 0.2068 - learning_rate: 1.5625e-05
# Epoch 55/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 465ms/step - accuracy: 0.9276 - loss: 0.2308 - val_accuracy: 0.9355 - val_loss: 0.2035 - learning_rate: 1.0000e-05
# Epoch 56/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 465ms/step - accuracy: 0.9162 - loss: 0.2438 - val_accuracy: 0.9316 - val_loss: 0.2038 - learning_rate: 1.0000e-05
# Epoch 57/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 478ms/step - accuracy: 0.9307 - loss: 0.2285 - val_accuracy: 0.9329 - val_loss: 0.2159 - learning_rate: 1.0000e-05
# Epoch 58/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9189 - loss: 0.2399 - val_accuracy: 0.9303 - val_loss: 0.2032 - learning_rate: 1.0000e-05
# Epoch 59/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 470ms/step - accuracy: 0.9230 - loss: 0.2393 - val_accuracy: 0.9368 - val_loss: 0.2018 - learning_rate: 1.0000e-05
# Epoch 60/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 462ms/step - accuracy: 0.9293 - loss: 0.2221 - val_accuracy: 0.9276 - val_loss: 0.2085 - learning_rate: 1.0000e-05
# Epoch 61/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 469ms/step - accuracy: 0.9341 - loss: 0.2106 - val_accuracy: 0.9316 - val_loss: 0.2003 - learning_rate: 1.0000e-05
# Epoch 62/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 470ms/step - accuracy: 0.9132 - loss: 0.2450 - val_accuracy: 0.9303 - val_loss: 0.1983 - learning_rate: 1.0000e-05
# Epoch 63/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.9198 - loss: 0.2250 - val_accuracy: 0.9316 - val_loss: 0.1976 - learning_rate: 1.0000e-05
# Epoch 64/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9257 - loss: 0.2221 - val_accuracy: 0.9316 - val_loss: 0.2101 - learning_rate: 1.0000e-05
# Epoch 65/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 476ms/step - accuracy: 0.9349 - loss: 0.2519 - val_accuracy: 0.9329 - val_loss: 0.2013 - learning_rate: 1.0000e-05
# Epoch 66/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 469ms/step - accuracy: 0.9294 - loss: 0.2317 - val_accuracy: 0.9342 - val_loss: 0.1910 - learning_rate: 1.0000e-05
# Epoch 67/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9372 - loss: 0.2117 - val_accuracy: 0.9303 - val_loss: 0.2003 - learning_rate: 1.0000e-05
# Epoch 68/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9246 - loss: 0.2230 - val_accuracy: 0.9355 - val_loss: 0.1885 - learning_rate: 1.0000e-05
# Epoch 69/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 474ms/step - accuracy: 0.9347 - loss: 0.2164 - val_accuracy: 0.9368 - val_loss: 0.1935 - learning_rate: 1.0000e-05

# %%
#results and visualisation on test set

#ploting training history
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

#confusion matrix
print("\n[info] generating confusion matrix on test dataa")

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_generator.classes

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix (Test Set)')
plt.show()

#classification report
print("\nclassification report")
print(classification_report(y_true, y_pred, target_names=class_names))

#savingg model
model.save('egyptian_money_custom_cnn.h5')
print("[infoooo] model saved as 'egyptian_money_custom_cnn.h5'")
# Out:
# [info] generating confusion matrix on test dataa
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 421ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#           10       0.92      0.97      0.94        35
#     10 (new)       1.00      1.00      1.00        30
#          100       0.91      0.91      0.91        35
#           20       0.91      0.86      0.88        35
#     20 (new)       1.00      0.97      0.98        30
#          200       0.94      0.86      0.90        35
#            5       0.85      0.94      0.89        35
#           50       0.86      0.86      0.86        35
#
#     accuracy                           0.92       290
#    macro avg       0.93      0.93      0.93       290
# weighted avg       0.93      0.92      0.92       290
#
# [infoooo] model saved as 'egyptian_money_custom_cnn.h5'

# %%
def plot_predictions(generator, model, num_images=9):
    images, labels = next(generator)
    predictions = model.predict(images)
    class_names = list(generator.class_indices.keys())

    plt.figure(figsize=(15, 10))

    for i in range(num_images):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])

        true_label_index = np.argmax(labels[i])
        pred_label_index = np.argmax(predictions[i])

        true_label = class_names[true_label_index]
        pred_label = class_names[pred_label_index]
        confidence = np.max(predictions[i]) * 100

        color = 'green' if true_label == pred_label else 'red'

        plt.title(f"True: {true_label}\nPred: {pred_label} ({confidence:.1f}%)",
                  color=color, fontsize=12, fontweight='bold')
        plt.axis('off')

    plt.tight_layout()
    plt.show()


print("[info] generating prediction grid")

plot_predictions(test_generator, model, num_images=9)
# Out:
# [info] generating prediction grid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
